# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Обработка-значений" data-toc-modified-id="Обработка-значений-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка значений</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучаем-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Гистограммы" data-toc-modified-id="Изучаем-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Гистограммы-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучаем параметры: площадь, цена, число комнат, высота потолков. Гистограммы</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Изучаем-время-продажи-квартиры" data-toc-modified-id="Изучаем-время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучаем время продажи квартиры</a></span></li><li><span><a href="#Изучаем-какие-факторы-больше-всего-влияют-на-стоимость-квартиры" data-toc-modified-id="Изучаем-какие-факторы-больше-всего-влияют-на-стоимость-квартиры-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучаем какие факторы больше всего влияют на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Изучаем-10-населённых-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="Изучаем-10-населённых-пунктов-с-наибольшим-числом-объявлений-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Изучаем 10 населённых пунктов с наибольшим числом объявлений</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Изучаем-предложения-квартир-в-Санк-Петербурге" data-toc-modified-id="Изучаем-предложения-квартир-в-Санк-Петербурге-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Изучаем предложения квартир в Санк-Петербурге</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Изучим-сегмент-квартир-в-центре" data-toc-modified-id="Изучим-сегмент-квартир-в-центре-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучим сегмент квартир в центре</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Изучаем-влияние-различных-факторов-на-цену-в-ценре-СПб" data-toc-modified-id="Изучаем-влияние-различных-факторов-на-цену-в-ценре-СПб-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Изучаем влияние различных факторов на цену в ценре СПб</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import numpy as np
import pandas as pd

# %%
#Исследование проводилось на датасете предоставленном Яндеекс.Практикум
df = pd.read_csv('/*******/************.csv', sep = '\t')

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Обнаружены пропуски в столбцах:
# ceiling_height
# floors_total
# living_area
# is_apartment
# kitchen_area
# balcony
# locality_name
# airports_nearest
# cityCenters_nearest
# parks_around3000
# parks_nearest
# ponds_around3000
# ponds_nearest
# days_exposition

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for column in df:
    print (column)
    try:
        print ('min:', df[column].min(), 'max:', df[column].max())
    except:
        print ('- -')
    print (df[column].unique())
# Out:
# total_images
# min: 0 max: 50
# [20  7 10  0  2  6  5 18  9  1 16 11  8 12 13  3 15 17 14 19 32  4 35 39
#  23 21 27 30 24 25 28 31 22 29 26 50 42 37]
# last_price
# min: 12190.0 max: 763000000.0
# [13000000.  3350000.  5196000. ...  6151120. 21400000. 11475000.]
# total_area
# min: 12.0 max: 900.0
# [108.    40.4   56.   ...  66.86 133.81  76.75]
# first_day_exposition
# min: 2014-11-27T00:00:00 max: 2019-05-03T00:00:00
# ['2019-03-07T00:00:00' '2018-12-04T00:00:00' '2015-08-20T00:00:00' ...
#  '2014-12-29T00:00:00' '2016-09-12T00:00:00' '2015-07-19T00:00:00']
# rooms
# min: 0 max: 19
# [ 3  1  2  4  5  6  0  7 11  8 14 10 15  9 19 16 12]
# ceiling_height
# min: 1.0 max: 100.0
# [  2.7     nan   3.03   2.5    2.67   2.56   3.05   2.75   2.6    2.9
#    2.8    2.55   3.     2.65   3.2    2.61   3.25   3.45   2.77   2.85
#    2.64   2.57   4.15   3.5    3.3    2.71   4.     2.47   2.73   2.84
#    3.1    2.34   3.4    3.06   2.72   2.54   2.51   2.78   2.76  25.
# ...

# %% [markdown]
# На что следует обратить внимание:
# Минимальное значение last_price - всего last_price
# Для каких-то объектов количество комнат (rooms) указано 0
# Высота потолков (ceiling_height) начинается от 1 метра, да и максимальное значние в 100 метров нереалистично. Есть значения вроде 26 или 32 - в них вероятно не отделили дробную часть (2.6 и 3.2).
# Значение в living_area начинаются от 2 метров - возможно, ошибка в данных.
# Площадь кухни стартует от 1.3 метра и достигает 112 метров - вероятно, снова есть ошибки при отделении дробной части.

# %%
for column in df:
    print(column,'\n', df[column].value_counts())
# Out:
# total_images
#  10    1798
# 9     1725
# 20    1694
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 14     986
# 4      986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     603
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 28       4
# 32       4
# 50       3
# 29       3
# 31       2
# 35       2
# 30       2
# 27       2
# 37       1
# 39       1
# 25       1
# 42       1
# Name: total_images, dtype: int64
# last_price
#  4500000.0     342
# 3500000.0     291
# 4000000.0     260
# 4300000.0     260
# 4200000.0     259
#              ...
# 4412094.0       1
# 6416000.0       1
# 4581000.0       1
# 34551000.0      1
# 6029433.0       1
# Name: last_price, Length: 2978, dtype: int64
# total_area
#  45.00     419
# 42.00     383
# 60.00     347
# 31.00     346
# 44.00     345
#          ...
# 45.85       1
# 44.18       1
# 59.83       1
# 127.20      1
# ...

# %%
df.sort_values('last_price')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 8793              7      12190.0       109.0  2019-03-20T00:00:00      2
# 17456             7     430000.0        30.4  2019-04-22T00:00:00      1
# 14911             5     430000.0        54.0  2018-06-26T00:00:00      2
# 16274            18     440000.0        40.0  2018-07-10T00:00:00      1
# 17676             0     450000.0        36.5  2018-02-01T00:00:00      1
# ...             ...          ...         ...                  ...    ...
# 15651            20  300000000.0       618.0  2017-12-18T00:00:00      7
# 1436             19  330000000.0       190.0  2018-04-04T00:00:00      3
# 14706            15  401300000.0       401.0  2016-02-20T00:00:00      5
# 19540             8  420000000.0       900.0  2017-12-06T00:00:00     12
# 12971            19  763000000.0       400.0  2017-09-30T00:00:00      7
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Одна строка с аномально низкой итоговой ценой  - можно удалить.

# %%
df.sort_values(['total_area'])
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 19904             4    2400000.0        12.0  2017-07-19T00:00:00      1
# 17961             3    1400000.0        13.0  2017-12-03T00:00:00      1
# 19546             3    1850000.0        13.0  2019-03-11T00:00:00      1
# 19807             0    3800000.0        13.0  2018-07-04T00:00:00      1
# 19558             2    1686000.0        13.2  2018-12-17T00:00:00      1
# ...             ...          ...         ...                  ...    ...
# 5358             20   65000000.0       590.0  2019-02-14T00:00:00     15
# 15651            20  300000000.0       618.0  2017-12-18T00:00:00      7
# 3117             19  140000000.0       631.0  2019-03-30T00:00:00      7
# 12859            20  140000000.0       631.2  2019-04-09T00:00:00      7
# 19540             8  420000000.0       900.0  2017-12-06T00:00:00     12
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# С площадью недвижимости пока всё выглядит неплохо.

# %%
df[df['rooms']==0]['rooms'].count()
# Out:
# 197

# %% [markdown]
# У 197 объектов 0 комнат. Проверим что это за объекты.

# %%
#df[df['rooms']==0].sort_values('total_area')
df[(df['rooms']==0) & (df['studio']==True)].sort_values('total_area')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8886             10   2450000.0        15.5  2018-08-22T00:00:00      0
# 716               5   1500000.0        17.0  2017-06-07T00:00:00      0
# 12996             8   1900000.0        18.0  2019-01-25T00:00:00      0
# 8755              1   1350000.0        18.8  2017-11-22T00:00:00      0
# 9817              8   2190000.0        19.0  2018-10-12T00:00:00      0
# ...             ...         ...         ...                  ...    ...
# 10008            20   5050000.0        44.2  2017-09-14T00:00:00      0
# 13613            16   8100000.0        58.4  2019-04-26T00:00:00      0
# 21227             0   8200000.0        71.0  2017-07-21T00:00:00      0
# 3458              6   7400000.0        73.6  2017-05-18T00:00:00      0
# 20082            10  16300000.0        98.4  2017-11-08T00:00:00      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# В основном это небольшие помещения, в которых, вероятно, одна комната.
# Сильно выделяется один объект - площадью 371 кв м, и с итоговой ценой 71000000.0 руб.
# Попробуем заполнить типичными значениями

# %% [markdown]
# ### Вывод

# %% [markdown]
# Во многих столбцах обнаружены пропуски, которые нужно будет обработать.
# Так же есть нехарактерные данные, которые нужно будет поправить, или удалить записи. На что следует обратить внимание:
# Минимальное значение last_price - всего last_price 12190.0 рублей - эту строку можно удалить.
# Для каких-то объектов количество комнат (rooms) указано 0
# Высота потолков (ceiling_height) начинается от 1 метра, да и максимальное значние в 100 метров нереалистично. Есть значения вроде 26 или 32 - в них вероятно не отделили дробную часть (2.6 и 3.2).
# Значение в living_area начинаются от 2 метров - возможно, ошибка в данных.
# В некоторых колонках можно заменить формат данных с float64 на int.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
#  Займемся пропусками
# - ceiling_height
# - floors_total
# + living_area
# + is_apartment
# + kitchen_area
# + balcony
# locality_name
# airports_nearest
# cityCenters_nearest
# + parks_around3000
# parks_nearest
# + ponds_around3000
# ponds_nearest
# days_exposition

# %% [markdown]
# Пропуски в ceiling_height и floors_total сложно заполнить какими-либо реалистичными данными.
# Займемся living_area.

# %%
df[df['living_area'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 7                 5   7915000.0       71.60  2019-04-18T00:00:00      2
# 30               12   2200000.0       32.80  2018-02-19T00:00:00      1
# 37               10   1990000.0       45.80  2017-10-28T00:00:00      2
# 44               13   5350000.0       40.00  2018-11-18T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23642            14   5950000.0       80.30  2018-07-03T00:00:00      3
# 23663            12   6400000.0       88.00  2018-01-12T00:00:00      4
# 23670             9   2450000.0       45.60  2018-02-08T00:00:00      1
# 23679             0   2500000.0       35.00  2017-12-08T00:00:00      1
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Для 1903 объектов не заполнена living_area.
# План: посчитать типичное соотношение жилой площади с общей площадью, заполнить пропуски перемножив общую площадь на полученный коэффициент. Отдельно обратим внимание на квартиры-студии и квартиры с открытой планировкой - вероятно, у них соотношение жилой площади  общей будет иным.

# %%
df['livin_total_ratio'] = df['living_area'] / df['total_area']

# %%
livin_total_ratio_studio = df.loc[(df['studio']==True) | (df['open_plan']==True), 'livin_total_ratio'].median()
livin_total_ratio = df['livin_total_ratio'].median()
df.loc[(df['studio']==True) | (df['open_plan']==True),'living_area'] = df.loc[(df['studio']==True) | (df['open_plan']==True),'living_area'].fillna((df['total_area']*livin_total_ratio_studio).round(decimals = 2))

# %%
df['living_area'] = df['living_area'].fillna((df['total_area']*livin_total_ratio).round(decimals = 2))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# Пропуски в living_area заполнены.

# %% [markdown]
# Аналогичным образом заполним пропуски в  kitchen_area

# %%
df.loc[df['kitchen_area'].isna(), :'kitchen_area']
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0  64900000.0       159.0  2015-07-24T00:00:00      3
# 30               12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37               10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44               13   5350000.0        40.0  2018-11-18T00:00:00      1
# 59               15   6300000.0        46.5  2017-03-06T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23655             1   2414306.0        40.5  2016-09-08T00:00:00      1
# 23663            12   6400000.0        88.0  2018-01-12T00:00:00      4
# 23670             9   2450000.0        45.6  2018-02-08T00:00:00      1
# 23679             0   2500000.0        35.0  2017-12-08T00:00:00      1
# 23696            18   2500000.0        56.7  2018-02-11T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# Для студий и квартир с открытой планировкой заполним площадь кухни равной 0.

# %%
df.loc[(df['open_plan'] == True) | (df['studio']==True), 'kitchen_area'] = df.loc[(df['open_plan'] == True) | (df['studio']==True), 'kitchen_area'].fillna(0)

# %%
df.query('open_plan == True or studio == True')['kitchen_area']
# Out:
# 144      0.0
# 349      0.0
# 440      0.0
# 508      0.0
# 608      0.0
#         ...
# 23210    0.0
# 23442    0.0
# 23554    0.0
# 23592    0.0
# 23637    0.0
# Name: kitchen_area, Length: 216, dtype: float64

# %%
df['kitchen_total_ratio'] = df['kitchen_area'] / df['total_area']
kitchen_total_ratio = df['kitchen_total_ratio'].median()
df['kitchen_area'] = df['kitchen_area'].fillna((df['total_area']*kitchen_total_ratio).round(decimals = 2))

# %%
df.loc[:, :'kitchen_area']
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
df['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски в kitchen_area заполнены типичными значениями.

# %% [markdown]
# Перейдем к is_apartment. Можно предположить, что отсутвствие значения равносильно "не апартаменты" - пропуски заполним значением False.

# %%
df['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %%
df['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Готово, вместо nan в столбце is_apartment теперь значения False.

# %% [markdown]
# Заполним пропуски в столбце balcony, аналогично как с is_apartment. Нет значения - нет балконов.

# %%
df['balcony'].value_counts()
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %%
df['balcony'] = df['balcony'].fillna(0)

# %%
df['balcony'].value_counts()
# Out:
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %%
df['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# Где не было данных о балконах - теперь нет балконов.

# %% [markdown]
# Зполним пропуски для близлежащих парков и водоемов. Если данных нет - будем считать, что в радиусе 3км нет парка/водоема.

# %%
df['parks_around3000'].value_counts()
# Out:
# 0.0    10106
# 1.0     5681
# 2.0     1747
# 3.0      647
# Name: parks_around3000, dtype: int64

# %%
df['ponds_around3000'].value_counts()
# Out:
# 0.0    9071
# 1.0    5717
# 2.0    1892
# 3.0    1501
# Name: ponds_around3000, dtype: int64

# %%
df['parks_around3000'] = df['parks_around3000'].fillna(0)
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)

# %%
df['parks_around3000'].value_counts()
# Out:
# 0.0    15624
# 1.0     5681
# 2.0     1747
# 3.0      647
# Name: parks_around3000, dtype: int64

# %%
df['parks_around3000'].isna().sum()
# Out:
# 0

# %%
df['ponds_around3000'].value_counts()
# Out:
# 0.0    14589
# 1.0     5717
# 2.0     1892
# 3.0     1501
# Name: ponds_around3000, dtype: int64

# %%
df['ponds_around3000'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски для водоемов и парков заполнены.

# %%
len(df.query('ponds_around3000>0'))
# Out:
# 9110

# %% [markdown]
# 9110 - количество записей у которых есть водоемы в радиусе 3000 м совпадает с количеством записей, для которых указано расстоние до ближайшего водоема. Значит, расстояние до ближайшего водоема заполняется только при наличии водоема в радиусе 3000 м. Заполнять каким-либо образом пропуски в ponds_nearest смысла нет.

# %%
len(df.query('parks_around3000>0'))
# Out:
# 8075

# %% [markdown]
# Парки в 3 км нашлись для 8075 записей. Расстояние до ближайшего парка заполнено для 8079 записей. Для 4 записей расстояние до парка заполнено, хоть парк не попал в радиус 3 км. Как видно в таблице ниже, расстояние там чуть превышает 3 км -- вероятно особенность выгрузки. Ситуация в целом аналогична ponds_nearest.
# Заполнять каким-либо образом пропуски в parks_nearest не будем.

# %%
df[df['parks_nearest'] > 3000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1590              3   7500000.0        70.0  2017-07-11T00:00:00      2
# 10959             9   3000000.0        31.1  2017-03-21T00:00:00      1
# 19208            17  14950000.0       187.0  2017-10-12T00:00:00      5
# 19430             9   3900000.0        30.5  2018-02-22T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1590              NaN          18.0         37.0     13         False  ...
# 10959             NaN           5.0         17.7      2         False  ...
# 19208             3.0           2.0         80.0      2         False  ...
# 19430             2.6           5.0         16.5      1         False  ...
#
#          locality_name  airports_nearest  cityCenters_nearest  \
# 1590   Санкт-Петербург           14878.0               9791.0
# 10959  Санкт-Петербург           14821.0               9734.0
# ...

# %% [markdown]
# Остались пропуски в следующих столбцах:
# - locality_name
# - airports_nearest
# - cityCenters_nearest
# - parks_nearest
# - ponds_nearest
# - days_exposition
# Местоположение мы не вычислим.
# Расстояние до аэропорта и центра города также неоткуда взять.
# расстояние до ближайшего парка и водоема не узнаем.
# Количество дней публикации вычислить из имеющихся данных нельзя - возможно такие записи все еще были опубликованы на момент выгрузки данных.

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Изменим тип данных с  float64 на int в следующих столбцах:
# balcony
# parks_around3000
# ponds_around3000
#
# В столбце first_day_exposition текстовые значения  переведем в формат даты и времени.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        23699 non-null float64
# ...

# %%
df[['balcony',
'parks_around3000',
'ponds_around3000']] = df[['balcony',
'parks_around3000',
'ponds_around3000']].astype(int)

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'],
format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Переведем столбец балконов в bool

# %%
df['balcony'] = df['balcony'].astype('bool')

# %% [markdown]
# Заменим тип в floors_total

# %%
df['floors_total'] = df['floors_total'].fillna(-999)

# %%
df['floors_total'] = df['floors_total'].astype('int')

# %%
df['floors_total'] = df['floors_total'].replace(-999, np.nan)

# %%
df.query('floors_total == -999')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, livin_total_ratio, kitchen_total_ratio]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['days_exposition'] = df['days_exposition'].fillna(-999)

# %%
df['days_exposition'] = df['days_exposition'].astype('int')

# %%
df['days_exposition'] = df['days_exposition'].replace(-999, np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null bool
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        23699 non-null int64
# ...

# %%
df['first_day_exposition']
# Out:
# 0       2019-03-07
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
#            ...
# 23694   2017-03-21
# 23695   2018-01-15
# 23696   2018-02-11
# 23697   2017-03-28
# 23698   2017-07-21
# Name: first_day_exposition, Length: 23699, dtype: datetime64[ns]

# %% [markdown]
# ### Обработка значений

# %% [markdown]
# Заменим нулевое количество комнат

# %%
df.groupby('rooms')['total_area'].describe()
# Out:
#         count        mean         std    min      25%     50%      75%    max
# rooms
# 0       197.0   29.279746   25.855264   15.5   24.050   26.05   28.400  371.0
# 1      8047.0   37.644669    9.338358   12.0   32.500   36.56   41.000  494.1
# 2      7940.0   55.855089   13.196340   20.0   46.000   53.00   62.000  196.0
# 3      5814.0   77.764580   23.268744   40.1   62.000   73.00   87.000  363.1
# 4      1180.0  107.610763   44.518981   42.0   77.800   99.30  125.325  500.0
# 5       326.0  161.474816   69.313733   40.0  117.475  146.45  183.750  507.0
# 6       105.0  201.537619   77.811206   87.0  152.000  184.30  236.000  500.0
# 7        59.0  265.325424  130.124168  100.6  181.700  214.00  347.300  631.2
# 8        12.0  259.233333   69.903171  150.0  224.325  235.70  323.975  373.1
# 9         8.0  305.975000   64.228760  235.0  249.975  300.95  334.250  400.0
# 10        3.0  259.566667   38.635519  216.1  244.350  272.60  281.300  290.0
# ...

# %% [markdown]
# Будем считать, что от 12 до 40 метров - однушки, от 40 до 62 - двушки, от 62 до 100 - трешки. Ну и нашему рекордсмену с 371 метром дадим 19 комнат.
# Для квартир-студий количество комнат менять не будем.

# %%
df.loc[(df['rooms'] == 0) & (12<df['total_area'])  & (df['total_area']<=40) & (df['studio']== False), 'rooms'] =1
df.loc[(df['rooms'] == 0) & (40<df['total_area'])  & (df['total_area']<=62) & (df['studio']== False), 'rooms'] =2
df.loc[(df['rooms'] == 0) & (62<df['total_area'])  & (df['total_area']<=100) & (df['studio']== False), 'rooms'] =3
df.loc[(df['rooms'] == 0) & (df['total_area']>300), 'rooms'] =19

# %%
df.query('rooms == 0 and 12<total_area<=40')['rooms']
# Out:
# 144      0
# 440      0
# 608      0
# 697      0
# 716      0
#         ..
# 22867    0
# 22877    0
# 23210    0
# 23554    0
# 23637    0
# Name: rooms, Length: 131, dtype: int64

# %%
df['rooms'].value_counts()
# Out:
# 1     8104
# 2     7941
# 3     5814
# 4     1180
# 5      326
# 0      138
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 19       2
# 11       2
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# С 0 комнат остались только квартиры-студии.

# %% [markdown]
# Поправим значения в столбце ceiling_height

# %%
df['ceiling_height'].value_counts().sort_values()
df['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   3.2 ,   2.61,
#          3.25,   3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,
#          3.3 ,   2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,
#          3.4 ,   3.06,   2.72,   2.54,   2.51,   2.78,   2.76,  25.  ,
#          2.58,   3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,
#          2.45,   3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,
#          3.16,   3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,
#          5.  ,   2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,
#          2.83,   4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,
#          3.18,   3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,
#          2.63,   3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,
#          3.66,   3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,
# ...

# %% [markdown]
# Посмотрим на неадекватно высокие потолки.

# %%
df.query('ceiling_height > 10')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17   3600000.0        55.2           2018-07-12      2
# 3148             14   2900000.0        75.0           2018-11-12      3
# 4643              0   4300000.0        45.0           2018-02-01      2
# 4876              7   3000000.0        25.0           2017-09-27      1
# 5076              0   3850000.0        30.5           2018-10-03      1
# 5246              0   2500000.0        54.0           2017-10-13      2
# 5669              4   4400000.0        50.0           2017-08-08      2
# 5807             17   8150000.0        80.0           2019-01-09      2
# 6246              6   3300000.0        44.4           2019-03-25      2
# 9379              5   3950000.0        42.0           2017-03-26      3
# 10773             8   3800000.0        58.0           2017-10-13      2
# 11285             0   1950000.0        37.0           2019-03-20      1
# ...

# %% [markdown]
# Допустим, бывают пентхаусы с высотой в 10.3 метра. Всё что больше, будем считать ошибкой пользователей - поделим на 10

# %%
df.loc[df['ceiling_height'] > 10.3, 'ceiling_height'] = df['ceiling_height']/10

# %% [markdown]
# Гугл подказывает, что минимально допустимая высота потолка в жилых помещениях 2,4 метра. Посмотрим, у каких объектов, высота оказалась меньше.

# %%
df.query('ceiling_height >= 10')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22309            20   5300000.0        45.0           2017-09-30      1
# 22869             0  15000000.0        25.0           2018-07-25      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 22309            10.3          16.0         15.5     15         False  ...
# 22869            10.0           5.0         14.0      5          True  ...
#
#          locality_name  airports_nearest  cityCenters_nearest  \
# 22309  Санкт-Петербург           36353.0              11936.0
# 22869  Санкт-Петербург           34963.0               8283.0
#
#        parks_around3000 parks_nearest  ponds_around3000  ponds_nearest  \
# 22309                 2         440.0                 2          450.0
# 22869                 1         223.0                 3           30.0
#
#        days_exposition  livin_total_ratio  kitchen_total_ratio
# ...

# %%
df[df['ceiling_height']<2.4]['ceiling_height'].value_counts()
# Out:
# 2.00    12
# 2.30     4
# 1.40     1
# 2.20     1
# 2.34     1
# 1.20     1
# 2.26     1
# 1.00     1
# 2.25     1
# 1.75     1
# Name: ceiling_height, dtype: int64

# %%
df[df['ceiling_height']<2.4]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 227              13   2200000.0       47.00           2018-01-12      3
# 552              11   2999000.0       33.50           2017-03-30      1
# 1582              4   4100000.0       45.60           2016-01-13      2
# 2572              4   2400000.0       62.00           2018-12-27      3
# 4212              1   2120000.0       35.43           2017-12-18      1
# 5498             17   2200000.0       56.00           2018-04-02      2
# 5712              5   1500000.0       42.80           2017-08-14      2
# 5850              9   1650000.0       35.50           2018-05-29      1
# 11352             4   3300000.0       36.00           2017-06-18      1
# 12755             2   1400000.0       22.50           2017-09-21      1
# 15061            19   5600000.0       56.40           2018-05-11      2
# 16446             6  12300000.0       88.30           2019-03-12      3
# ...

# %% [markdown]
# Всего 21 объект, в основном в многоэтажных домах. Наверняка пользователи ошиблись при вводе данных. Заменим на 2,5 метра.

# %%
df.loc[df['ceiling_height']<2.4, 'ceiling_height'] = 2.5

# %%
df[df['ceiling_height']<2.4]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, livin_total_ratio, kitchen_total_ratio]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Замена произведена успешно.

# %%
df.query('ceiling_height > 5')['ceiling_height'].value_counts()
# Out:
# 8.0     3
# 5.3     2
# 5.8     1
# 10.3    1
# 5.2     1
# 8.3     1
# 5.6     1
# 10.0    1
# 6.0     1
# 5.5     1
# Name: ceiling_height, dtype: int64

# %%
df['ceiling_height'].unique()
# Out:
# array([ 2.7 ,   nan,  3.03,  2.5 ,  2.67,  2.56,  3.05,  2.75,  2.6 ,
#         2.9 ,  2.8 ,  2.55,  3.  ,  2.65,  3.2 ,  2.61,  3.25,  3.45,
#         2.77,  2.85,  2.64,  2.57,  4.15,  3.5 ,  3.3 ,  2.71,  4.  ,
#         2.47,  2.73,  2.84,  3.1 ,  3.4 ,  3.06,  2.72,  2.54,  2.51,
#         2.78,  2.76,  2.58,  3.7 ,  2.52,  5.2 ,  2.87,  2.66,  2.59,
#         2.45,  3.6 ,  2.92,  3.11,  3.13,  3.8 ,  3.15,  3.55,  3.16,
#         3.62,  3.12,  2.53,  2.74,  2.96,  2.46,  5.3 ,  5.  ,  2.79,
#         2.95,  4.06,  2.94,  3.82,  3.54,  3.53,  2.83,  4.7 ,  2.4 ,
#         3.38,  3.01,  5.6 ,  3.65,  3.9 ,  3.18,  3.35,  3.57,  2.48,
#         2.62,  2.82,  3.98,  2.63,  3.83,  3.52,  3.95,  3.75,  2.88,
#         3.67,  3.87,  3.66,  3.85,  3.86,  4.19,  3.24,  4.8 ,  4.5 ,
#         4.2 ,  3.36,  3.08,  3.68,  3.07,  3.37,  3.09,  8.  ,  3.26,
#         3.34,  2.81,  3.44,  2.97,  3.14,  4.37,  2.68,  3.22,  3.27,
# ...

# %% [markdown]
# Попробуем выделить записи с неадекватно малой жилой площадью

# %%
df.query('living_area<7').sort_values(by=['total_area'])
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 17582            11   2680000.0        22.0           2018-08-11      0
# 21758             0   2330000.0        23.0           2018-01-01      0
# 16431            13   3799000.0        31.0           2018-04-12      1
# 19251            19   4050000.0        33.0           2018-10-15      1
# 3242              7   4440000.0        41.0           2017-07-02      1
# 13915            20   6350000.0        52.0           2018-02-06      2
# 21943            15   6100000.0        77.6           2019-02-28      4
# 23574            14  64990000.0       139.0           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 17582             NaN          25.0          5.0      8         False  ...
# 21758             NaN          24.0          2.0     22         False  ...
# 16431             2.6           5.0          6.0      1         False  ...
# ...

# %% [markdown]
# Таких объектов оказалось совсем немного (для квартир очень малой площади, вероятно, и малая жилплощадь не ошибка). Можно пренебречь исправлением этих записей.

# %% [markdown]
# Также проверим, что нет квартир, где жилая площадь превышает общую.

# %%
df.query('livin_total_ratio>1')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, livin_total_ratio, kitchen_total_ratio]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Таких нет.

# %% [markdown]
# Обработаем значения населенных пунктов: уберем тип населенного пункта, заменим в названиях букву ё на е.

# %% [markdown]
# Для начала попробуем выделить леммы, чтобы понять какие слова используются для обозначения типа населенного пункта

# %%
from pymystem3 import Mystem
m = Mystem()

# %%
df['locality_name'] = df['locality_name'].fillna('неизвестно')

# %% [markdown]
# Удалим типы населенных пунктов из названий.

# %%
df['locality_name'] = df['locality_name'].replace(regex='ё', value = "е").str.strip()

# %%
df.query('"Бугры" in locality_name')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, livin_total_ratio, kitchen_total_ratio]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['locality_name'].value_counts().head(60)
# Out:
# Санкт-Петербург                            15721
# поселок Мурино                               556
# поселок Шушары                               440
# Всеволожск                                   398
# Пушкин                                       369
# Колпино                                      338
# поселок Парголово                            327
# Гатчина                                      307
# деревня Кудрово                              299
# Выборг                                       237
# Петергоф                                     201
# Сестрорецк                                   183
# Красное Село                                 178
# Кудрово                                      173
# деревня Новое Девяткино                      144
# Сертолово                                    142
# Ломоносов                                    133
# Кириши                                       125
# поселок Бугры                                114
# ...

# %% [markdown]
# Воссоединим Мурино с поселком Мурино, а Кудрово с деревней Кудрово

# %%
df.loc[df['locality_name']== "Мурино", 'locality_name'] = "поселок Мурино"
df.loc[df['locality_name']== "Кудрово", 'locality_name'] = "деревня Кудрово"

# %%
df['locality_name'].value_counts().head(15)
# Out:
# Санкт-Петербург            15721
# поселок Мурино               590
# деревня Кудрово              472
# поселок Шушары               440
# Всеволожск                   398
# Пушкин                       369
# Колпино                      338
# поселок Парголово            327
# Гатчина                      307
# Выборг                       237
# Петергоф                     201
# Сестрорецк                   183
# Красное Село                 178
# деревня Новое Девяткино      144
# Сертолово                    142
# Name: locality_name, dtype: int64

# %% [markdown]
# ### Выводы
# Заполнили пропуски в столбцах, где это было целесообразно и возможно (living_area, is_apartment, kitchen_area, balcony, parks_around3000, ponds_around3000).
# Заменили типы данных с вещественного на целочисленный, чтобы с данными было удобно работать (balcony, parks_around3000, ponds_around3000). Дату размещения объявления привели к формату даты - так сможем получать из неё отдельные параметры.
# Исправили высоту потолков, там где она была судя по всему указана некорректно.
# Из столбца с названиями населенных пунктов удалили тип населенного пункта, заменили "ё" на "е", чтобы по названиям можно было группировать.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Добавим в таблицу цену квадратного метра

# %%
df['meter_price'] = (df['last_price'] / df['total_area']).astype('int')

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Добавим день недели, месяц и год публикации объявления

# %%
df['first_day_exposition_day'] = pd.DatetimeIndex(df['first_day_exposition']).dayofweek
df['first_day_exposition_month'] = pd.DatetimeIndex(df['first_day_exposition']).month
df['first_day_exposition_year'] = pd.DatetimeIndex(df['first_day_exposition']).year

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1             NaN          11.0        18.60      1         False  ...
# ...

# %% [markdown]
# Добавим в таблицу этаж квартиры; варианты — первый, последний, другой. Если полное количество этажей в строке не заполнено, и этаж не первый - квартира попадет в категорию "другой".

# %%
df['floor_cat'] = df['floor']

def floor_cat(row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
df['floor_cat'] = df.apply(floor_cat, axis = 1)

# %% [markdown]
# Проверим результаты присвоения категорий

# %%
df['floor_cat'].value_counts()
# Out:
# другой       17446
# последний     3336
# первый        2917
# Name: floor_cat, dtype: int64

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1             NaN          11.0        18.60      1         False  ...
# 2             NaN           5.0        34.30      4         False  ...
# 3             NaN          14.0        90.29      9         False  ...
# 4            3.03          14.0        32.00     13         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  livin_total_ratio  \
# ...

# %%
df[df['floor_cat']=='последний'].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 12            10   3890000.0        54.0           2016-06-30      2
# 13            20   3550000.0        42.8           2017-07-01      2
# 23            11   2950000.0        32.0           2016-10-29      1
# 36            13   3790000.0        45.0           2017-01-25      2
# 43            13   9330000.0        48.0           2017-01-10      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 12             NaN           5.0         30.0      5         False  ...
# 13            2.56           5.0         27.0      5         False  ...
# 23            2.60           9.0         17.7      9         False  ...
# 36             NaN           9.0         27.0      9         False  ...
# 43            3.00           4.0         28.0      4         False  ...
#
#     ponds_around3000  ponds_nearest  days_exposition  livin_total_ratio  \
# ...

# %% [markdown]
# Столбцы с соотношением жилой и общей площади, а также отношением площади кухни к общей мы уже добавили в таблицу на этапе заполнения пропущенных значений. Это столбцы livin_total_ratio и kitchen_total_ratio соответственно.

# %% [markdown]
# ### Вывод
# Мы успешно рассчитали и добавили в таблицу следующие данные:
# - цену квадратного метра;
# - день недели, месяц и год публикации объявления;
# - этаж квартиры; варианты — первый, последний, другой;
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ###  Изучаем параметры: площадь, цена, число комнат, высота потолков. Гистограммы

# %% [markdown]
# Изучим следующие параметры: площадь, цена, число комнат, высота потолков.
# Построим гистограммы для каждого параметра.

# %%
import matplotlib.pyplot as plt

# %%
plt.ylim(0,150)
df.boxplot(column='total_area', figsize = (7,20))
plt.show()

# %%
df['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
df['total_area'].hist(bins=50)
plt.show()

# %% [markdown]
# Из-за наличия нескольких "дворцов" с очень большой площадью по гистограмме сложно что-то сказать. Ограничим диапозон, выведем объекты площадью до 120 метров (судя по "ящику с усами" дальше всё равно идут выбросы), также добавим больше корзин для наглядности.

# %%
df['total_area'].hist(bins=100, range=(12, 120))
plt.show()

# %% [markdown]
# Гистограмма по площадям квартир выглядит правдоподобно. Пики в районе 30 и 45 метров. Это примерно соответствует площади одно- и двух-комнатных квартир в "хрущевках".
# Убедимся, посчитав значения (см ниже) - больше всего квартир площадью 44, 42, 45 метров.

# %%
df['total_area'].value_counts().sort_values()
# Out:
# 23.55       1
# 154.70      1
# 151.17      1
# 192.30      1
# 129.70      1
#          ...
# 44.00     345
# 31.00     346
# 60.00     347
# 42.00     383
# 45.00     419
# Name: total_area, Length: 2182, dtype: int64

# %% [markdown]
# Построим гистограмму по цене

# %%
df['last_price'].hist(bins=100)
plt.show()

# %% [markdown]
# Дворцы стоят недёшево, а на нашей гистограмме из-за этого ничего не понятно.

# %%
plt.ylim(0,17000000)
df.boxplot(column='last_price', figsize = (7,10))
plt.show()

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
df['last_price'].describe()
# Out:
# count       23699.000
# mean      6541548.772
# std      10887013.268
# min         12190.000
# 25%       3400000.000
# 50%       4650000.000
# 75%       6800000.000
# max     763000000.000
# Name: last_price, dtype: float64

# %%
df['last_price'].plot(kind = 'hist', bins=100, range=(0, 12000000), rot = 45)
plt.ticklabel_format(axis="x", style="plain")
plt.show()

# %% [markdown]
# Теперь видно, что большинство значений попадают в диапозон до 12 миллионов рублей, а пик находится в районе 4 миллионов.
# Выбросов не наблюдается, выглядит корректно.

# %% [markdown]
# Построим гистограмму по числу комнат

# %%
df['rooms'].describe()
# Out:
# count   23699.000
# mean        2.074
# std         1.080
# min         0.000
# 25%         1.000
# 50%         2.000
# 75%         3.000
# max        19.000
# Name: rooms, dtype: float64

# %%
df['rooms'].hist(bins=20)
plt.show()

# %% [markdown]
# Всё выглядит корректно, большинство квартир 1-, 2-, 3-комнатные

# %%
df['rooms'].value_counts()
# Out:
# 1     8104
# 2     7941
# 3     5814
# 4     1180
# 5      326
# 0      138
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 19       2
# 11       2
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# Построим гистограмму для высоты потолков.

# %%
df['ceiling_height'].describe()
# Out:
# count   14504.000
# mean        2.730
# std         0.304
# min         2.400
# 25%         2.510
# 50%         2.650
# 75%         2.800
# max        10.300
# Name: ceiling_height, dtype: float64

# %%
df['ceiling_height'].hist(bins=50)
plt.show()

# %% [markdown]
# Большинство значений уместились до 4,5 метров. Ограничим диапозон.

# %%
df['ceiling_height'].hist(bins=50, range = (2,5))
plt.show()

# %% [markdown]
# Выглядит правдоподобно. Пики ожидаемо в районе 2,5 и 2,7 метров - самые распространенные варианты высоты потолка.

# %% [markdown]
# #### Выводы
# Построили гистограммы для площади, цены, числа комнат, высоты потолков. Судя по диаграммам распределение всех значений выгляди реалистичным.

# %% [markdown]
# ### Изучаем время продажи квартиры

# %% [markdown]
# Построим гистограмму для времени продажи квартиры

# %%
df['days_exposition'].hist(bins = 30)
plt.show()

# %% [markdown]
# Рассмотрим подробнее диапозон от 0 до 200

# %%
df['days_exposition'].hist(bins = 50, range = (0,200), figsize = (10,5))
plt.show()

# %%
df['days_exposition'].value_counts().sort_values().tail(15)
# Out:
# 18.000    129
# 11.000    135
# 44.000    138
# 20.000    139
# 8.000     139
# 9.000     143
# 14.000    148
# 5.000     152
# 3.000     158
# 4.000     176
# 90.000    204
# 30.000    208
# 7.000     234
# 60.000    538
# 45.000    880
# Name: days_exposition, dtype: int64

# %% [markdown]
# Явные пики на 60 и 45 дней, также среди самых частых значений 30 и 90. Возможно это стандартные сроки размещения объявления, либо значения округлялись. Также в топе 7 и 14 дней - тоже выглядит как некая стандатизация.

# %% [markdown]
# Найдём среднее и медиану

# %%
df['days_exposition'].describe()
# Out:
# count   20518.000
# mean      180.889
# std       219.728
# min         1.000
# 25%        45.000
# 50%        95.000
# 75%       232.000
# max      1580.000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Среднее больше медианы почти в два раза. Всё из-за объявлений, которые размещены др 4 и более лет.
# Будем судить по квартилям: если сделку закрыли меньше чем за 45 дней - продажи пошли быстро, если больше чем за 230 дней - медленно.
# Обычный срок продажи квартиры - 95 дней.

# %% [markdown]
# Предположим, что если объявления было размещено в течение стандартного срока, то это означает, что продажа не состоялась (не пришлось снимать объявление с публикации раньше). Попробуем изучить время продажи квартиры без "стандартных" значений (7,14,30,45,60,90 дней).

# %%
days_exposition_false = [7, 14, 30, 45, 60, 90]
df.query('days_exposition not in @days_exposition_false')['days_exposition'].describe()
# Out:
# count   18306.000
# mean      197.273
# std       227.082
# min         1.000
# 25%        46.000
# 50%       115.000
# 75%       261.000
# max      1580.000
# Name: days_exposition, dtype: float64

# %%
df.query('days_exposition not in @days_exposition_false')['days_exposition']
# Out:
# 0           nan
# 1        81.000
# 2       558.000
# 3       424.000
# 4       121.000
#           ...
# 23693   239.000
# 23694       nan
# 23696       nan
# 23697   602.000
# 23698       nan
# Name: days_exposition, Length: 21487, dtype: float64

# %% [markdown]
# Не все значения (7,14,30,45,60,90 дней) не исключаются из выборки

# %%
df[df['days_exposition'] == 45]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 78                9 4350000.000      37.000           2018-02-22      1
# 89                9 2500000.000      63.000           2018-10-25      3
# 110               6 3850000.000      72.300           2017-09-29      2
# 153              12 4350000.000      55.000           2017-05-21      2
# 158              15 3100000.000      47.300           2017-11-07      2
# ...             ...         ...         ...                  ...    ...
# 23601            10 2900000.000      43.400           2018-01-11      2
# 23613             4 3950000.000      52.000           2018-03-04      3
# 23670             9 2450000.000      45.600           2018-02-08      1
# 23679             0 2500000.000      35.000           2017-12-08      1
# 23695            14 3100000.000      59.000           2018-01-15      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Срез по одному из значений (45) не строится. Попробуем перевести значения столбца в int

# %%
df['days_exposition'] = df['days_exposition'].fillna(-1)
df['days_exposition']
# Out:
# 0        -1.000
# 1        81.000
# 2       558.000
# 3       424.000
# 4       121.000
#           ...
# 23694    -1.000
# 23695    45.000
# 23696    -1.000
# 23697   602.000
# 23698    -1.000
# Name: days_exposition, Length: 23699, dtype: float64

# %%
df['days_exposition'] = df['days_exposition'].astype('int')

# %%
import numpy as np
df['days_exposition'] = df['days_exposition'].replace(-1, np.nan)

# %%
df.query('days_exposition not in @days_exposition_false')['days_exposition']
# Out:
# 0           nan
# 1        81.000
# 2       558.000
# 3       424.000
# 4       121.000
#           ...
# 23693   239.000
# 23694       nan
# 23696       nan
# 23697   602.000
# 23698       nan
# Name: days_exposition, Length: 21487, dtype: float64

# %% [markdown]
# Значения перевели в int, пропуски вернули на место. Изучим теперь показатели среза еще раз.

# %%
df.query('days_exposition not in @days_exposition_false')['days_exposition'].describe()
# Out:
# count   18306.000
# mean      197.273
# std       227.082
# min         1.000
# 25%        46.000
# 50%       115.000
# 75%       261.000
# max      1580.000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Медианный срок породажи квартиры теперь 115 дней (был 95 дней).
# Быстрой можно считать сделку прошедшую меньше, чем за 46 дней, а долгой - больше,чем за 261 день (ранее было 45 и 230 дней соответственно).

# %% [markdown]
# ### Изучаем какие факторы больше всего влияют на стоимость квартиры

# %% [markdown]
# Рассмотрим влияние площади квартиры на цену.

# %%
df.query('total_area < 400 and last_price < 50000000').plot(x='total_area', y='last_price', kind='scatter', alpha=0.3, figsize = (12,5), title = 'Зависимость цены от общей площади')

# %%
print(df['total_area'].corr(df['last_price']))
# Out:
# 0.6536750579657244

# %% [markdown]
# Предсказуемо, чем больше площадь, тем выше цена.

# %% [markdown]
# Посмотрим как цена зависит от количества комнат.

# %%
df.query('last_price<50000000').plot(x='rooms', y='last_price', kind='scatter', alpha=0.3, figsize = (12,8),title = 'Зависимость цены от количества комнат')

# %%
print(df['rooms'].corr(df['last_price']))
# Out:
# 0.3662869698945045

# %% [markdown]
# Цена квартир растет с количеством комнат, однако корреляция не очень сильная.

# %%
df.query('last_price<50000000').plot(x='cityCenters_nearest', y='last_price', kind='scatter', alpha=0.3, figsize = (12,8),grid = True ,title = 'Зависимость цены от расстояния до центра')

# %%
df['cityCenters_nearest'].corr(df['last_price'])
# Out:
# -0.20674734874298376

# %%
df.query('cityCenters_nearest<20000')['cityCenters_nearest'].corr(df['last_price'])
# Out:
# -0.2704395586947481

# %% [markdown]
# Чем ближе к центру, тем цены ниже. Корреляция не очень сильная. Близость к центру практически перестает сказываться на ценах после 20 км.

# %%
df.pivot_table(index = 'floor_cat', values = 'last_price', aggfunc = 'median').plot(
    kind = 'bar', grid = True, rot = 0, ylim = 3000000,
    title = 'Медианная цена в зависимости от этажа')
plt.show()

# %% [markdown]
# Самые дешевые квартиры на первом этаже, на последнем несколько дороже, самые дорогие - на "другом". Квартиры на первом этаже как правило примерно на 20% дешевле тех, что расположились на "другом".

# %%
df.pivot_table(index = 'first_day_exposition_day', values = 'last_price', aggfunc = 'median').plot(grid=True, title = 'Медианная цена по дням недели')
plt.show()

# %% [markdown]
# Чем ближе к выходным размещено объявление, тем меньше медианная цена. Может объявлени с дорогими объектами размещают агенты по недвижимости, поэтому это происходит в будние дни?

# %%
df.query('last_price<50000000').plot(
    x='first_day_exposition_day', y='last_price', kind='scatter', alpha=0.3, figsize = (12,8),grid = True,title = 'Цена по дням недели')
plt.show()

# %% [markdown]
# Посмотрим на зависимость цены от месяца подачи объявления.

# %%
df.pivot_table(index = 'first_day_exposition_month', values = 'last_price', aggfunc = 'median').plot(
    grid = True,title = 'Цена по месяцам')
plt.show()

# %%
df.query('last_price<50000000').plot(
    x='first_day_exposition_month', y='last_price', kind='scatter', alpha=0.3, 
    figsize = (12,8),grid = True,title = 'Цена по месяцам')
plt.show()

# %% [markdown]
# По графику изменения медианной цены видно, что выделяются три месяца. При этом для апрельских объявлений цены максимальные, а вот в мае и июне - минимальные.
# Вероятно спад связан с сезоном отпусков и затишьем на рынке.

# %% [markdown]
# Посмотрим на зависимость цены от года подачи объявления.

# %%
df.pivot_table(index = 'first_day_exposition_year', values = 'last_price', aggfunc = 'median').plot(
    grid = True,title = 'Медианная цена по годам')
plt.show()

# %%
df.query('last_price<50000000').plot(
    x='first_day_exposition_year', y='last_price', kind='scatter', 
    alpha=0.3, figsize = (12,8),grid = True,title = 'Медианная цена по годам')
plt.show()

# %% [markdown]
# Медианная цена после 2014го года упала сразу на треть, а потом и еще немного. Явное влияние экономического кризиса 2014-15 годов.

# %% [markdown]
# #### Выводы
# Наибольшее влияние на цену имеет площадь квартиры и этаж (дороде квартиры, размещенные не на певом и не на последем этажах). Количество комнат и расстояние до центра влияют на цену умеренно.
# Цена объектов, размещенных в будние дни, заметно выше цены объектов, размещенных в выходные. В мае и июне наблюдается спад цен, в то время как пик - в апреле. После 2014 года цены на недвижимость резко упали и в последующие 5 лет оставались приблизительно на одном уровне.

# %% [markdown]
# ### Изучаем 10 населённых пунктов с наибольшим числом объявлений

# %% [markdown]
# Выберем 10 населённых пунктов с наибольшим числом объявлений

# %%
top10 = df.groupby('locality_name')['locality_name'].count().sort_values(ascending = False).head(10)

# %%
top10
# Out:
# locality_name
# Санкт-Петербург      15721
# поселок Мурино         590
# деревня Кудрово        472
# поселок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# поселок Парголово      327
# Гатчина                307
# Выборг                 237
# Name: locality_name, dtype: int64

# %% [markdown]
# Получим список названий населенных пунктов из топ 10.

# %%
top10_index = top10.index

# %%
top10_index
# Out:
# Index(['Санкт-Петербург', 'поселок Мурино', 'деревня Кудрово',
#        'поселок Шушары', 'Всеволожск', 'Пушкин', 'Колпино',
#        'поселок Парголово', 'Гатчина', 'Выборг'],
#       dtype='object', name='locality_name')

# %% [markdown]
# Перепроверим, что выборка по полученному списку даёт то же количетво обявлений.

# %%
df.query('locality_name in @top10_index')['locality_name'].value_counts()
# Out:
# Санкт-Петербург      15721
# поселок Мурино         590
# деревня Кудрово        472
# поселок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# поселок Парголово      327
# Гатчина                307
# Выборг                 237
# Name: locality_name, dtype: int64

# %% [markdown]
# Убедимся, что в нашей выборке во всех строках есть данные для расчета цены квадратного метра (цена и общая площадь).

# %%
df.query('locality_name in @top10_index').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19199 entries, 0 to 23697
# Data columns (total 29 columns):
# total_images                  19199 non-null int64
# last_price                    19199 non-null float64
# total_area                    19199 non-null float64
# first_day_exposition          19199 non-null datetime64[ns]
# rooms                         19199 non-null int64
# ceiling_height                11837 non-null float64
# floors_total                  19122 non-null float64
# living_area                   19199 non-null float64
# floor                         19199 non-null int64
# is_apartment                  19199 non-null bool
# studio                        19199 non-null bool
# open_plan                     19199 non-null bool
# kitchen_area                  19199 non-null float64
# balcony                       19199 non-null bool
# locality_name                 19199 non-null object
# airports_nearest              17107 non-null float64
# ...

# %% [markdown]
# Все данные есть. Рассчитаем цену квадратного метра. Сначала сохраним в новом датафрейме только нужные нам данные.

# %%
Meter_price = df.query('locality_name in @top10_index')[['locality_name', 'last_price', 'total_area']]

# %%
Meter_price
# Out:
#          locality_name   last_price  total_area
# 0      Санкт-Петербург 13000000.000     108.000
# 1       поселок Шушары  3350000.000      40.400
# 2      Санкт-Петербург  5196000.000      56.000
# 3      Санкт-Петербург 64900000.000     159.000
# 4      Санкт-Петербург 10000000.000     100.000
# ...                ...          ...         ...
# 23689  Санкт-Петербург  3550000.000      35.300
# 23690  Санкт-Петербург  5500000.000      52.000
# 23691  Санкт-Петербург  9470000.000      72.900
# 23694  Санкт-Петербург  9700000.000     133.810
# 23697  Санкт-Петербург 11475000.000      76.750
#
# [19199 rows x 3 columns]

# %% [markdown]
# Добавим новый столбец с ценой квадратного метра

# %%
Meter_price['m2_price'] = Meter_price['last_price'] / Meter_price['total_area']

# %% [markdown]
# Выведем таблицу со средними показателями.

# %%
Meter_price.groupby('locality_name').mean().sort_values(by = 'm2_price', ascending = False).reset_index()
# Out:
#        locality_name  last_price  total_area   m2_price
# 0    Санкт-Петербург 8062507.069      64.751 114849.009
# 1             Пушкин 6469035.946      61.553 103125.819
# 2    деревня Кудрово 4358688.051      46.395  95324.931
# 3  поселок Парголово 4488074.798      51.521  90175.913
# 4     поселок Мурино 3678462.203      44.099  86087.512
# 5     поселок Шушары 4108081.816      53.821  78677.364
# 6            Колпино 3964021.438      53.231  75424.579
# 7            Гатчина 3488336.678      50.943  68746.147
# 8         Всеволожск 3789067.751      56.022  68654.474
# 9             Выборг 3250983.122      56.150  58141.909

# %% [markdown]
# #### Выводы
# Из 10 населенных пунктов с самым большим количеством объявлений, самая высокая средняя цена квадратного метра в Санк-Петербурге. Самая низкая - в Выборге.

# %% [markdown]
# ### Изучаем предложения квартир в Санк-Петербурге

# %%
df.query('locality_name == "Санкт-Петербург"').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15721 entries, 0 to 23697
# Data columns (total 29 columns):
# total_images                  15721 non-null int64
# last_price                    15721 non-null float64
# total_area                    15721 non-null float64
# first_day_exposition          15721 non-null datetime64[ns]
# rooms                         15721 non-null int64
# ceiling_height                10104 non-null float64
# floors_total                  15651 non-null float64
# living_area                   15721 non-null float64
# floor                         15721 non-null int64
# is_apartment                  15721 non-null bool
# studio                        15721 non-null bool
# open_plan                     15721 non-null bool
# kitchen_area                  15721 non-null float64
# balcony                       15721 non-null bool
# locality_name                 15721 non-null object
# airports_nearest              15636 non-null float64
# ...

# %% [markdown]
# Не для всех квартир в СПб указано расстояние до центра.
# В датафрейм добавим столбец с расстоянием о центра в километрах - отберём только те квартиры, для которых расстояние до центра указано.

# %%
df['cityCenters_nearest_km'] = df['cityCenters_nearest']

# %%
df.loc[df['cityCenters_nearest'].notnull(),'cityCenters_nearest_km'] = (df['cityCenters_nearest_km']/1000).round(0)

# %%
df
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.000     108.000           2019-03-07      3
# 1                 7  3350000.000      40.400           2018-12-04      1
# 2                10  5196000.000      56.000           2015-08-20      2
# 3                 0 64900000.000     159.000           2015-07-24      3
# 4                 2 10000000.000     100.000           2018-06-19      2
# ...             ...          ...         ...                  ...    ...
# 23694             9  9700000.000     133.810           2017-03-21      3
# 23695            14  3100000.000      59.000           2018-01-15      3
# 23696            18  2500000.000      56.700           2018-02-11      2
# 23697            13 11475000.000      76.750           2017-03-28      2
# 23698             4  1350000.000      32.300           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
spb_flats = df.query('locality_name == "Санкт-Петербург" and cityCenters_nearest_km.notnull()').reset_index()

# %%
spb_flats
# Out:
#        index  total_images   last_price  total_area first_day_exposition  \
# 0          0            20 13000000.000     108.000           2019-03-07
# 1          2            10  5196000.000      56.000           2015-08-20
# 2          3             0 64900000.000     159.000           2015-07-24
# 3          4             2 10000000.000     100.000           2018-06-19
# 4          7             5  7915000.000      71.600           2019-04-18
# ...      ...           ...          ...         ...                  ...
# 15655  23689            13  3550000.000      35.300           2018-02-28
# 15656  23690             3  5500000.000      52.000           2018-07-19
# 15657  23691            11  9470000.000      72.900           2016-10-13
# 15658  23694             9  9700000.000     133.810           2017-03-21
# 15659  23697            13 11475000.000      76.750           2017-03-28
#
#        rooms  ceiling_height  floors_total  living_area  floor  ...  \
# ...

# %%
spb_flats['m2_price'] = spb_flats['last_price'] / spb_flats['total_area']

# %%
spb_flats.groupby('cityCenters_nearest_km')['last_price'].mean().plot(
    grid = True, figsize = (12,5), xlim = (-0.1,15),
    title = 'Зависимость средней цены от удленности от центра')
plt.show()

# %%
spb_flats.groupby('cityCenters_nearest_km')['m2_price'].mean().plot(
    grid = True, figsize = (12,5), xlim = (-0.1,15),
    title = 'Зависимость средней цены метра от удленности от центра')
plt.show()

# %% [markdown]
# ####  Выводы
# Цены резко идут в гору в радиусе 2 километров от центра Санкт-Петербурга. Будем считать это центральной зоной.

# %% [markdown]
# ### Изучим сегмент квартир в центре

# %% [markdown]
# Выделим в датафрейме квартиры в СПб, в радиусе 2 км от центра.

# %%
center_flats = df.query('locality_name == "Санкт-Петербург" and cityCenters_nearest_km.notnull() and cityCenters_nearest_km<=2')

# %%
center_flats
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 24                8  6500000.000      97.200           2015-10-31      2
# 155               8 96000000.000     317.000           2017-07-07      4
# 207              11  9000000.000      72.600           2018-09-08      2
# 213              11  8700000.000     111.400           2016-10-10      4
# 226              17  7950000.000      86.400           2019-04-24      4
# ...             ...          ...         ...                  ...    ...
# 23395             4 40000000.000     188.000           2017-05-29      6
# 23399            16 15300000.000      97.000           2017-01-11      3
# 23400            17 30000000.000     213.000           2017-09-28      7
# 23602             0  8700000.000      73.000           2019-01-23      3
# 23648            14 10100000.000      78.000           2017-05-12      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Нашли 529 квартир.
# Построим гистограмму по площади.

# %%
center_flats['total_area'].hist(bins = 50)

plt.show()

# %%
center_flats['total_area'].describe()
# Out:
# count   529.000
# mean    104.163
# std      60.582
# min      12.000
# 25%      66.100
# 50%      90.000
# 75%     122.000
# max     517.000
# Name: total_area, dtype: float64

# %% [markdown]
# Медианная площадь продаваемой квартиры в центре Питера - 90 метров. Это значительно больше медианной площади для всех квартир (52 метра).

# %% [markdown]
# Посмотрим на цены

# %%
center_flats['last_price'].describe()
# Out:
# count         529.000
# mean     19726267.688
# std      32729408.892
# min       2100000.000
# 25%       8000000.000
# 50%      10700000.000
# 75%      16900000.000
# max     401300000.000
# Name: last_price, dtype: float64

# %%
center_flats['last_price'].hist(bins = 50)

# %% [markdown]
# Ограничим выборку

# %%
center_flats.query('last_price < (1*10**8)')['last_price'].hist(bins = 50, xrot = 45)
plt.ticklabel_format(axis="x", style="plain")
plt.show()

# %% [markdown]
# Медианная цена квартиры в центре Питера 10,7 млн рублей. На графике всё выглядит корректно, ненатуральных пиков не видно.

# %% [markdown]
# Изучим квартиры по числу комнат

# %%
center_flats['rooms'].hist(bins = 15)

# %% [markdown]
# В сравнении с общей статистикой, в центре относительно немного однокомнатных квартир, зато доля 4-х и 5-и комнатных квартир достатосно высокая.

# %% [markdown]
# Изучим высоту потолков в центре Питера.

# %%
center_flats['ceiling_height'].hist(bins = 15)

# %%
center_flats['ceiling_height'].describe()
# Out:
# count   372.000
# mean      3.242
# std       0.409
# min       2.500
# 25%       3.000
# 50%       3.200
# 75%       3.500
# max       5.800
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Медианная высота потолков в центре Питера 3,2 метра, в то время как по всему региону - сего 2,65 метра.
# На графике хорошо видно, что преобладаю квартиры с высотой потолков от 3 метров.

# %% [markdown]
# #### Выводы
# Медианная площадь продаваемой квартиры в центре Питера - 90 метров. Это значительно больше медианной площади для всех квартир (52 метра).
# В сравнении с общей статистикой, в центре относительно немного однокомнатных квартир, зато доля 4-х и 5-и комнатных квартир достатосно высокая.
# Медианная высота потолков в центре Питера 3,2 метра, в то время как по всему региону - сего 2,65 метра.
# Вероятно в центре Питера много старого жилья  с высокими потолками, и, возможно, нового дорогостоящего.

# %% [markdown]
# ### Изучаем влияние различных факторов на цену в ценре СПб

# %% [markdown]
# Рассмотрим влияние площади квартиры на цену.

# %%
center_flats.query('total_area < 400 and last_price < 50000000').plot(x='total_area', y='last_price', kind='scatter', alpha=0.3, figsize = (12,5))

# %%
print(center_flats['total_area'].corr(center_flats['last_price']))
# Out:
# 0.567712230866888

# %% [markdown]
# Чем больше площадь, тем выше цена. Корреляция немного меньше, чем для всего региона.

# %% [markdown]
# Посмотрим как цена зависит от количества комнат.

# %%
center_flats.query('last_price<50000000').plot(x='rooms', y='last_price', kind='scatter', alpha=0.3, figsize = (12,8))

# %%
print(center_flats['rooms'].corr(center_flats['last_price']))
# Out:
# 0.21858279869065203

# %% [markdown]
# Цена квартир растет с количеством комнат, однако корреляция не очень сильная, притом даже меньше чем для всего региона.

# %% [markdown]
# Посмотрим как на цену влияет близость к центру.

# %%
center_flats.query('last_price<50000000').plot(x='cityCenters_nearest', y='last_price', kind='scatter', alpha=0.3, figsize = (12,8),grid = True)

# %%
center_flats['cityCenters_nearest'].corr(center_flats['last_price'])
# Out:
# -0.07066296776853934

# %% [markdown]
# Корреляция совсем слабая - это подтвепждает что центральная зона определена верно. Любые объекты в этой зоне нахоятся в одинаковой ценовой категории.

# %%
center_flats.pivot_table(index = 'floor_cat', values = 'last_price', aggfunc = 'median').plot(
    kind = 'bar', grid = True, rot = 0, ylim = 5000000,
    title = 'Медианная цена в зависимости от этажа')
plt.show()

# %% [markdown]
# Самые дешевые квартиры на первом этаже, на последнем несколько дороже, самые дорогие - на "другом". Картина практически не отличается от той, что мы видели для всего региона.

# %% [markdown]
# Посмотрим как день недели размещения влияет на цену.

# %%
center_flats.pivot_table(index = 'first_day_exposition_day', values = 'last_price', aggfunc = 'median').plot()

# %% [markdown]
# Нет такой явной зависимости, как при исследовании всего региона, но всё же квартиры выставленны на продажу на выходных чуть дешевле.

# %% [markdown]
# Посмотрим на зависимость цены от месяца подачи объявления.

# %%
center_flats.pivot_table(index = 'first_day_exposition_month', values = 'last_price', aggfunc = 'median').plot(grid = True)

# %% [markdown]
# В целом картина похожа на то, что мы видели для всего региона. С мая по июль наблюдается падения медианной цены. Максимальные цены для квартир в центе  - в январе.

# %% [markdown]
# Посмотрим на зависимость цены от года подачи объявления.

# %%
center_flats.pivot_table(index = 'first_day_exposition_year', values = 'last_price', aggfunc = 'median').plot(grid = True)

# %%
center_flats.query('last_price<50000000').plot(x='first_day_exposition_year', y='last_price', kind='scatter', alpha=0.3, figsize = (12,8),grid = True)

# %% [markdown]
# Для квартир в центре, кк и для всего региона наблюдается резкое падение цен после 2014 года. Однако за 2014 год для центра Питера совсе мало объявлений, поэтому есл бы мы рассматривали только центр, то эти данные были бы ненадежны.

# %% [markdown]
# # Общий вывод

# %% [markdown]
# + Построили гистограммы для площади, цены, числа комнат, высоты потолков. Судя по диаграммам распределение всех значений выгляди реалистичным.
# + Проанализировали время продажи квартиры. Медианный срок породажи квартиры 115 дней. Быстрой можно считать сделку прошедшую меньше, чем за 46 дней, а долгой - больше,чем за 261 день. При этом были обнаружены и удалены предполагаемыее выбросы: для большого количества объявлений срок размещения был указан равным 7, 14, 30, 45, 60, 90 дням -- вероятно, по этим объявлениям продажа не состоялась, а объявления были сняты с публикации после истеччения стандартного срока.
# + Наибольшее влияние на цену имеет площадь квартиры и этаж (дороде квартиры, размещенные не на певом и не на последем этажах). Количество комнат и расстояние до центра влияют на цену умеренно.
# Цена объектов, размещенных в будние дни, заметно выше цены объектов, размещенных в выходные. В мае и июне наблюдается спад цен, в то время как пик - в апреле. После 2014 года цены на недвижимость резко упали и в последующие 5 лет оставались приблизительно на одном уровне.
# + Из 10 населенных пунктов с самым большим количеством объявлений, самая высокая средняя цена квадратного метра в Санк-Петербурге. Самая низкая - в Выборге.
# + Центральной зоной Санкт-Петербурга определили зону в радиусе 2 километров от центра.
# + Медианная площадь продаваемой квартиры в центре Питера - 90 метров. Это значительно больше медианной площади для всех квартир (52 метра).
# В сравнении с общей статистикой, в центре относительно немного однокомнатных квартир, зато доля 4-х и 5-и комнатных квартир достатосно высокая.
# Медианная высота потолков в центре Питера 3,2 метра, в то время как по всему региону - сего 2,65 метра.
# + В центре корреляция площади и цены немного меньше, чем для всего региона, то же можно сказать и про корреляцию цены с количеством комнат.
# Самые дешевые квартиры в центре на первом этаже, на последнем несколько дороже, самые дорогие - на "другом". Картина практически не отличается от той, что мы видели для всего региона.
